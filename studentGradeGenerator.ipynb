# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-Saad-Awan/ATM-Machine-/blob/main/studentGradeGenerator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Student Report Card Generator

def get_student_data():
    students = []

    while True:
        try:
            print("\nEnter Student Details:")
            name = input("Student Name: ")
            roll = input("Roll Number: ")

            math = int(input("Math Marks: "))
            physics = int(input("Physics Marks: "))
            urdu = int(input("Urdu Marks: "))
            english = int(input("English Marks: "))
            computer = int(input("Computer Marks: "))

            total = math + physics + urdu + english + computer
            percentage = total / 5

            # Grade Assignment
            if percentage >= 80:
                grade = "A+"
            elif percentage >= 70:
                grade = "A"
            elif percentage >= 60:
                grade = "B"
            elif percentage >= 50:
                grade = "C"
            elif percentage >= 40:
                grade = "F"
            else:
                grade = "Fail"

            students.append({
                'name': name,
                'roll': roll,
                'Math': math,
                'Physics': physics,
                'Urdu': urdu,
                'English': english,
                'Computer': computer,
                'Total': total,
                'Percentage': percentage,
                'Grade': grade
            })

            print(f"\nRecord of {name} inserted successfully.")

            choice = input("Do you want to insert more? Press 'Y' for Yes or 'N' for No: ").strip().upper()
            while choice not in ['Y', 'N']:
                choice = input("Invalid input. Please enter 'Y' or 'N': ").strip().upper()

            if choice == 'N':
                break

        except ValueError:
            print("Invalid input! Please enter numeric values for marks.")

    return students


def display_report_cards(students):
    print("\n\n========== Report Cards ==========")
    for student in students:
        print("\n-----------------------------")
        print(f"Name       : {student['name']}")
        print(f"Roll No    : {student['roll']}")
        print(f"Math       : {student['Math']}")
        print(f"Physics    : {student['Physics']}")
        print(f"Urdu       : {student['Urdu']}")
        print(f"English    : {student['English']}")
        print(f"Computer   : {student['Computer']}")
        print(f"Total Marks: {student['Total']}")
        print(f"Percentage : {student['Percentage']:.2f}%")
        print(f"Grade      : {student['Grade']}")
        print("-----------------------------")



students_list = get_student_data()
display_report_cards(students_list)
# Out:
# Enter Student Details:
# Student Name: Muhammad Saad
# Roll Number: 23-CS-63
# Math Marks: 67
# Physics Marks: 75
# Urdu Marks: 81
# English Marks: 77
# Computer Marks: 69
#
# Record of Muhammad Saad inserted successfully.
# Do you want to insert more? Press 'Y' for Yes or 'N' for No: N
#
#
# ========== Report Cards ==========
#
# -----------------------------
# Name       : Muhammad Saad
# Roll No    : 23-CS-63
# Math       : 67
# Physics    : 75
# Urdu       : 81
# English    : 77
# Computer   : 69
# Total Marks: 369
# Percentage : 73.80%
# Grade      : A
# -----------------------------
